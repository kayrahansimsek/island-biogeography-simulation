# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("values.csv")
df1 = df.copy()
df["species_change"] = pd.NA

# %%
def StringtoList(string):
    x = string.strip('][').split(', ')
    for i in range(len(x)):
        x[i] = float(x[i])
    return x

# %%
for row in range(len(df)):
    df.islands_size[row] = StringtoList(df.islands_size[row])
    df.island_capacity[row] = StringtoList(df.island_capacity[row])
    df.islands_distance[row] = StringtoList(df.islands_distance[row])
    df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
    df.individual_count[row] = StringtoList(df.individual_count[row])
    if row == 0:
        df.species_change[row] = [0,0,0]
    else:
        change = [df.islands_diversity[row][i] - df.islands_diversity[row - 1][i] for i in range(len(df.islands_diversity[row]))]
        df.species_change[row] = change
# Out:
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = [0,0,0]
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_size[row] = StringtoList(df.islands_size[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.island_capacity[row] = StringtoList(df.island_capacity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_distance[row] = StringtoList(df.islands_distance[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.islands_diversity[row] = StringtoList(df.islands_diversity[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.individual_count[row] = StringtoList(df.individual_count[row])
# C:\Users\kayra\AppData\Local\Temp\ipykernel_24976\900083496.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.species_change[row] = change
